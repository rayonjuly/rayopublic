# %%
from google import genai
from google.genai import types
import pathlib
import os
import io

# %%
client = genai.Client(api_key='AIzaSyBnAay2md3L_-ukZcLpQP84U_7SU5jvL9A')

filepath = pathlib.Path(r'D:\5. Minh và Hương\3. Temp - Tài liệu luận văn chị Lương\Vietnamese\Vietnamese\1. ORC Bàn về QH.pdf')

prompt = """
Trích xuất những thông tin sau:
- tên file
- tên tài liệu
- tên tác giả
- tên nhà xuất bản
- năm xuất bản
- tên tài liệu dịch sang tiếng Pháp
- tên tác giả dịch sang tiếng Pháp (không quan tâm có phải tên riêng hay không, tên tác giả thường đi kèm học hàm học vị như Giáo sư hay Tiến sĩ, tôi cần bạn dịch những học hàm học vị này sang tiếng Pháp. Với tên người bằng Tiếng Việt thì bỏ dấu. Với tên cơ quan, tổ chức thì cũng dịch sang tiếng Pháp) 
- tên nhà xuất bản dịch sang tiếng Pháp
Trình bày kết quả ở bảng để tôi có thể export ra file spreadsheet. Nếu thông tin được viết dưới dạng in hoa thì sửa lại thành dạng chữ thường nhưng viết hoa đúng chính tả.
"""

response = client.models.generate_content(
  model="gemini-2.5-flash",
  contents=[
      types.Part.from_bytes(
        data=filepath.read_bytes(),
        mime_type='application/pdf',
      ),
      prompt])

response
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# Cell In [10], line 18
#       3 filepath = pathlib.Path(r'D:\5. Minh và Hương\3. Temp - Tài liệu luận văn chị Lương\Vietnamese\Vietnamese\1. ORC Bàn về QH.pdf')
#       5 prompt = """
#       6 Trích xuất những thông tin sau:
#       7 - tên file
#    (...)
#      15 Trình bày kết quả ở dạng pandas dataframe
#      16 """
# ---> 18 response = client.models.generate_content(
#      19   model="gemini-2.5-flash",
#      20   contents=[
#      21       types.Part.from_bytes(
#      22         data=filepath.read_bytes(),
#      23         mime_type='application/pdf',
#      24       ),
#      25       prompt])
#      27 response
#
# ...
